# %% [markdown]
# <a href="https://colab.research.google.com/github/papa-fololo/Repo1/blob/master/RFwithlags.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#so far undertaken in this notebook
#RF normal prediction
#feature importance to remove unhelpful features
#grid search to optimize
#7 day time lag added to exogenous results
#scaling of

# %%
import pandas as pd
import xgboost as xgb
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error, r2_score, explained_variance_score, mean_absolute_error
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rentals = pd.read_csv("bikedata1.csv")

data = rentals

data.head()
# Out:
#        dteday  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 0  01/01/2011       1   0     1        0        6           0           2
# 1  01/02/2011       1   0     1        0        0           0           2
# 2  01/03/2011       1   0     1        0        1           1           1
# 3  01/04/2011       1   0     1        0        2           1           1
# 4  01/05/2011       1   0     1        0        3           1           1
#
#        temp     atemp       hum  windspeed  rentals
# 0  0.344167  0.363625  0.805833   0.160446      331
# 1  0.363478  0.353739  0.696087   0.248539      131
# 2  0.196364  0.189405  0.437273   0.248309      120
# 3  0.200000  0.212122  0.590435   0.160296      108
# 4  0.226957  0.229270  0.436957   0.186900       82

# %%
data['dteday'] = pd.to_datetime(data['dteday']).dt.date
data=data.set_index('dteday')
data.head()
# Out:
#             season  yr  mnth  holiday  weekday  workingday  weathersit  \
# dteday
# 2011-01-01       1   0     1        0        6           0           2
# 2011-01-02       1   0     1        0        0           0           2
# 2011-01-03       1   0     1        0        1           1           1
# 2011-01-04       1   0     1        0        2           1           1
# 2011-01-05       1   0     1        0        3           1           1
#
#                 temp     atemp       hum  windspeed  rentals
# dteday
# 2011-01-01  0.344167  0.363625  0.805833   0.160446      331
# 2011-01-02  0.363478  0.353739  0.696087   0.248539      131
# 2011-01-03  0.196364  0.189405  0.437273   0.248309      120
# 2011-01-04  0.200000  0.212122  0.590435   0.160296      108
# 2011-01-05  0.226957  0.229270  0.436957   0.186900       82

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 731 entries, 2011-01-01 to 2012-12-31
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      731 non-null    int64
#  1   yr          731 non-null    int64
#  2   mnth        731 non-null    int64
#  3   holiday     731 non-null    int64
#  4   weekday     731 non-null    int64
#  5   workingday  731 non-null    int64
#  6   weathersit  731 non-null    int64
#  7   temp        731 non-null    float64
#  8   atemp       731 non-null    float64
#  9   hum         731 non-null    float64
#  10  windspeed   731 non-null    float64
#  11  rentals     731 non-null    int64
# dtypes: float64(4), int64(8)
# memory usage: 74.2+ KB

# %%
fig, ax = plt.subplots(2,1,figsize=(12, 4))
data.temp.plot(ax=ax[0], label='temp', linewidth=1)
data.rentals.plot(ax=ax[1], label='rentals', linewidth=1)
#X_test.Close.plot(ax=ax, label='test', linewidth=1)
#plt.set_title('Temp normal')
plt.legend();

# %%
from statsmodels.graphics.tsaplots import plot_acf


# Plot the ACF for the target variable
plot_acf(data['rentals'], lags=7, alpha=0.01)

# Set the plot labels and title
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.title('Autocorrelation Plot for Target Variable')

# Display the plot
plt.show()

# %%
# Introduce weekly time lag for entire dataset; then split but include rental lag
lag = 7  # Weekly time lag

for col in data:
    data[f'{col}_lag{lag}'] = data[col].shift(lag)

data.head()

# Create X and y test/train split where shuffle is set to False
#X = df_clean[['a', 'b', 'c', 'd', 'a_lag7', 'b_lag7', 'c_lag7', 'd_lag7']]
#y = df_clean['e']
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
# Out:
#             season  yr  mnth  holiday  weekday  workingday  weathersit  \
# dteday
# 2011-01-01       1   0     1        0        6           0           2
# 2011-01-02       1   0     1        0        0           0           2
# 2011-01-03       1   0     1        0        1           1           1
# 2011-01-04       1   0     1        0        2           1           1
# 2011-01-05       1   0     1        0        3           1           1
#
#                 temp     atemp       hum  ...  mnth_lag7  holiday_lag7  \
# dteday                                    ...
# 2011-01-01  0.344167  0.363625  0.805833  ...        NaN           NaN
# 2011-01-02  0.363478  0.353739  0.696087  ...        NaN           NaN
# 2011-01-03  0.196364  0.189405  0.437273  ...        NaN           NaN
# 2011-01-04  0.200000  0.212122  0.590435  ...        NaN           NaN
# 2011-01-05  0.226957  0.229270  0.436957  ...        NaN           NaN
#
#             weekday_lag7  workingday_lag7  weathersit_lag7  temp_lag7  \
# dteday
# 2011-01-01           NaN              NaN              NaN        NaN
# 2011-01-02           NaN              NaN              NaN        NaN
# 2011-01-03           NaN              NaN              NaN        NaN
# 2011-01-04           NaN              NaN              NaN        NaN
# 2011-01-05           NaN              NaN              NaN        NaN
#
#             atemp_lag7  hum_lag7  windspeed_lag7  rentals_lag7
# dteday
# 2011-01-01         NaN       NaN             NaN           NaN
# 2011-01-02         NaN       NaN             NaN           NaN
# 2011-01-03         NaN       NaN             NaN           NaN
# 2011-01-04         NaN       NaN             NaN           NaN
# 2011-01-05         NaN       NaN             NaN           NaN
#
# [5 rows x 24 columns]

# %%
X = data[['temp', 'temp_lag7','rentals_lag7']]
y = data['rentals']

# Split data 70%-30% into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0, shuffle = False)

print ('Training Set: %d rows\nTest Set: %d rows' % (X_train.shape[0], X_test.shape[0]))
# Out:
# Training Set: 511 rows
# Test Set: 220 rows

# %%
X_train.head(), y_train.head()
# Out:
# (                temp  temp_lag7  rentals_lag7
#  dteday
#  2011-01-01  0.344167        NaN           NaN
#  2011-01-02  0.363478        NaN           NaN
#  2011-01-03  0.196364        NaN           NaN
#  2011-01-04  0.200000        NaN           NaN
#  2011-01-05  0.226957        NaN           NaN,
#  dteday
#  2011-01-01    331
#  2011-01-02    131
#  2011-01-03    120
#  2011-01-04    108
#  2011-01-05     82
#  Name: rentals, dtype: int64)

# %%
y_train_N = y_train.iloc[7:]
y_train_N.head()
# Out:
# dteday
# 2011-01-08    68
# 2011-01-09    54
# 2011-01-10    41
# 2011-01-11    43
# 2011-01-12    25
# Name: rentals, dtype: int64

# %%
X_train_df = pd.DataFrame(data = X_train)
X_test_df = pd.DataFrame(data = X_test)
y_train_df = pd.DataFrame(data = y_train)
y_test_df = pd.DataFrame(data = y_test)

y_test_df.head()
# Out:
#             rentals
# dteday
# 2012-05-26     2855
# 2012-05-27     3283
# 2012-05-28     2557
# 2012-05-29      880
# 2012-05-30      745

# %%
X_train_N=X_train.dropna()
X_test_N=X_test.dropna()

missing = X_train.isnull()

# create a bar plot of missing values by column
plt.bar(missing.columns, missing.sum())
plt.title('Columns with Missing Values')
plt.xlabel('Column')
plt.ylabel('Number of Missing Values')
plt.show()

# %%
X_train_N.head()
# Out:
#                 temp  temp_lag7  rentals_lag7
# dteday
# 2011-01-08  0.165000   0.344167         331.0
# 2011-01-09  0.138333   0.363478         131.0
# 2011-01-10  0.150833   0.196364         120.0
# 2011-01-11  0.169091   0.200000         108.0
# 2011-01-12  0.172727   0.226957          82.0

# %%
# Train the model
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
import numpy as np

model = RandomForestRegressor().fit(X_train_N, y_train_N)
print (model, "\n")

# Evaluate the model using the test data
predictions = model.predict(X_test_N)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2model = r2_score(y_test, predictions)
print("R2:", r2model)
# Out:
# RandomForestRegressor()
#
# MSE: 239390.87024999992
# RMSE: 489.2758631385774
# R2: 0.5471373750955693

# %%
mae = mean_absolute_error(y_test, predictions)
print("MAE:", mae)
# Out:
# MAE: 354.30600000000004

# %%
y_test_df['RF'] = predictions

y_test_df.head()
# Out:
#             rentals       RF
# dteday
# 2012-05-26     2855  2033.29
# 2012-05-27     3283  2443.46
# 2012-05-28     2557   696.18
# 2012-05-29      880  1034.57
# 2012-05-30      745   827.19

# %%
#predictions1['Date/Time'] = predictions1['Date/Time'].dt.strftime('%Y-%m-%d')
# Time series plot
# ==============================================================================
fig, ax = plt.subplots(figsize=(12, 4))
#data.rentals.plot(ax=ax, label='train', linewidth=1)
#data.rentals.plot(ax=ax, label='actual', linewidth=1)
y_test_df.rentals.plot(ax=ax, label='predGB', linewidth=1)
y_test_df.RF.plot(ax=ax, label='predRF', linewidth=1)

ax.set_title('test chart')
ax.legend();

# %%
# Use grid search to find the best hyperparameters
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [200, 300, 1000],
    'max_depth': [5, 10, 25],
    'min_samples_split': [4, 8, 26]
}

grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=10)
grid_search.fit(X_train_N, y_train_N)

# Get the best model from the grid search
best_rf = grid_search.best_estimator_
model2 = best_rf

# Predict on the test dataset using the best hyperparameters
pred2 = best_rf.predict(X_test)

# %%
y_test_df['RF2'] = pred2

y_test_df.head()
# Out:
#             rentals       RF          RF2
# dteday
# 2012-05-26     2855  2033.29  1998.377287
# 2012-05-27     3283  2443.46  2183.232603
# 2012-05-28     2557   696.18   747.182605
# 2012-05-29      880  1034.57   849.429724
# 2012-05-30      745   827.19   781.733095

# %%
#predictions1['Date/Time'] = predictions1['Date/Time'].dt.strftime('%Y-%m-%d')
# Time series plot
# ==============================================================================
fig, ax = plt.subplots(figsize=(12, 4))
#data.rentals.plot(ax=ax, label='train', linewidth=1)
#data.rentals.plot(ax=ax, label='actual', linewidth=1)
y_test_df.rentals.plot(ax=ax, label='actual', linewidth=1)
y_test_df.RF.plot(ax=ax, label='RF1', linewidth=1)
y_test_df.RF2.plot(ax=ax, label='RF1', linewidth=1)

ax.set_title('test chart')
ax.legend();

# %%
mse2 = mean_squared_error(y_test, pred2)
print("MSE:", mse2)
rmse2 = np.sqrt(mse2)
print("RMSE:", rmse2)
r2model2 = r2_score(y_test, pred2)
print("R2:", r2model2)
mae2 = mean_absolute_error(y_test, pred2)
print("MAE:", mae2)
# Out:
# MSE: 217320.8232281386
# RMSE: 466.1768154124984
# R2: 0.5888879206182398
# MAE: 334.08968297293364

# %%
mae2 = mean_absolute_error(y_test, pred2)
print("MAE:", mae2)
# Out:
# MAE: 334.08968297293364

# %%
print("MSE:", mse, mse2)

print("RMSE:", rmse,rmse2)

print("R2:", r2model, r2model2)

print("mae:", mae, mae2)
# Out:
# MSE: 239390.87024999992 217320.8232281386
# RMSE: 489.2758631385774 466.1768154124984
# R2: 0.5471373750955693 0.5888879206182398
# mae: 354.30600000000004 334.08968297293364

# %%
# Plot the feature importance
feature_importance = model2.feature_importances_
plt.bar(X.columns, feature_importance)
plt.xlabel('Features')
plt.ylabel('Importance')
plt.show()
